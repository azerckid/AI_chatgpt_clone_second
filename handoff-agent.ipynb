# %%
from agents import Agent, Runner, SQLiteSession

session = SQLiteSession("user_1", "ai-memory.db")


geaography_agent = Agent(
    name="Geo Expert Agent",
    instructions="You are a expert in geography, you answer questions related to them.",
    handoff_description="Use this to answer geography related questions.",
)
economics_agent = Agent(
    name="Economics Expert Agent",
    instructions="You are a expert in economics, you answer questions related to them.",
    handoff_description="Use this to answer economics questions.",
)

main_agent = Agent(
    name="Main Agent",
    instructions="You are a user facing agent. Transfer to the agent most capable of answering the user's question.",
    handoffs=[
        economics_agent,
        geaography_agent,
    ],
)

# %%
result = await Runner.run(
    main_agent,
    "Why do countries sell bonds?",
    session=session,
)

print(result.last_agent.name)
print(result.final_output)
# Out:
# Economics Expert Agent
# Countries sell bonds primarily to raise money for government spending and to manage their finances. Here are the key reasons:
#
# 1. Financing Budget Deficits: If a government spends more than it collects in taxes and other revenue, it needs to borrow money to cover the gap. Issuing bonds is the most common way to do this.
#
# 2. Funding Public Projects: Money from bonds can be used for infrastructure projects (roads, schools, hospitals), social programs, defense, and more.
#
# 3. Managing Debt: Governments may issue new bonds to pay off older bonds that are maturing, a process called "rolling over" the debt.
#
# 4. Monetary Policy: Central banks sometimes use bond sales as a tool to influence money supply and interest rates in the economy.
#
# 5. Providing Safe Investments: Government bonds are usually considered low-risk, so they provide a safe investment option for individuals, banks, pension funds, and foreign investors.
#
# In summary, countries issue bonds to finance their activities without having to immediately raise taxes or cut spending, and to manage economic stability.
